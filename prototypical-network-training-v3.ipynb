# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/5way-5shot/train_LSA64_5way_5shot_suppot_query.csv
# /kaggle/input/5way-5shot/test_LSA64_5way_5shot_suppot_query.csv
# /kaggle/input/te-v3-model/model_epoch_70.pt

# %%
from sklearn.metrics import accuracy_score,silhouette_score 
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import csv
import ast
import torch.nn.functional as F
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import LabelEncoder
import random
from torch.optim import Adam
from torch.nn.functional import cross_entropy
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Your code for loading the data (unchanged)
input_file = "/kaggle/input/5way-5shot/train_LSA64_5way_5shot_suppot_query.csv"

values = []
matrix_labels = []
num_rows = 0

with open(input_file, "r") as f_input:
    reader = csv.reader(f_input)
    for row in reader:
        row_values = []
        for i in range(len(row) - 1):
            column_value = ast.literal_eval(row[i])
            row_values.append(column_value)
        values.append(torch.tensor(row_values))
        matrix_labels.append(ast.literal_eval(row[-1]))
        num_rows += 1
        
matrix_labels = np.array(matrix_labels)

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, n_features, d_model=32, nhead=32, num_layers=1):
        super(TransformerEncoder, self).__init__()
        self.embedding = nn.Linear(n_features, d_model)
        self.positional_encoding = self.generate_positional_encoding(d_model)
        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model, nhead), num_layers
        )

    def generate_positional_encoding(self, d_model, max_len=243):
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model)
        )
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        return pe.unsqueeze(0)

    def forward(self, x):
        x = self.embedding(x)
        x = x + self.positional_encoding[:, : x.size(1)]
        x = self.transformer_encoder(x)
        x = x.mean(dim=1)
        return x

# %%
class PrototypicalNetworks(nn.Module):
    def __init__(self, backbone: nn.Module):
        super(PrototypicalNetworks, self).__init__()
        self.backbone = backbone

    def forward(
        self,
        support_images: torch.Tensor,
        support_labels: torch.Tensor,
        query_images: torch.Tensor,
    ) -> torch.Tensor:
        """
        Predict query labels using labeled support images.
        """
        # Extract the features of support and query images
        z_support = self.backbone.forward(support_images)
        z_query = self.backbone.forward(query_images)

        # Infer the number of different classes from the labels of the support set
        n_way = len(torch.unique(support_labels))
        # Prototype i is the mean of all instances of features corresponding to labels == i
        z_proto = torch.cat(
            [
                z_support[torch.nonzero(support_labels == label)].mean(0)
                for label in range(n_way)
            ]
        )
#         print(z_proto.shape)
#         print(z_query.shape, z_proto.shape)
        # Compute the euclidean distance from queries to prototypes
        dists = torch.cdist(z_query, z_proto)
#         print(dists.shape)
        # And here is the super complicated operation to transform those distances into classification scores!
        scores = -dists
        return scores

# %%
# Load the data and split it into training and testing sets
# train_values, test_values, train_matrix_labels, test_matrix_labels = train_test_split(values, matrix_labels, test_size=0.2, random_state=42, stratify=matrix_labels)

train_values = torch.stack(values)
train_matrix_labels = matrix_labels

# %%
# Load the saved TransformerEncoder model
saved_model_path = "/kaggle/input/te-v3-model/model_epoch_70.pt"

# Instantiate the TransformerEncoder as the backbone
n_features = 114
encoder = TransformerEncoder(n_features=n_features)
encoder.load_state_dict(torch.load(saved_model_path))
# Out:
# <All keys matched successfully>

# %%
# embeddings = encoder(torch.stack(values))

# %%
model = PrototypicalNetworks(encoder)

# %%
def create_few_shot_task(embeddings, labels, n_way, k_shot, n_query):
    unique_labels = np.unique(labels)
    selected_labels = np.random.choice(unique_labels, n_way, replace=False)
    
    # Create a dictionary for mapping the original labels to the new labels
    label_map = {label: idx for idx, label in enumerate(selected_labels)}
    
    support_set = []
    query_set = []
    support_labels = []
    query_labels = []
    
    for label in selected_labels:
        class_embeddings = embeddings[labels == label]
        if len(class_embeddings) < k_shot + n_query:
            continue
        support_indices = np.random.choice(range(len(class_embeddings)), k_shot, replace=False)
        query_indices = np.random.choice(np.delete(range(len(class_embeddings)), support_indices), n_query, replace=False)
        
        support_set.append(class_embeddings[support_indices].detach().numpy())
        query_set.append(class_embeddings[query_indices].detach().numpy())
        support_labels.extend([label_map[label]] * k_shot)
        query_labels.extend([label_map[label]] * n_query)
    
    support_set = np.concatenate(support_set, axis=0)
    query_set = np.concatenate(query_set, axis=0)
    support_labels = np.array(support_labels)
    query_labels = np.array(query_labels)
    
    return support_set, query_set, support_labels, query_labels

# %%
# Training parameters
n_epochs = 100
n_way = 5
k_shot = 5
n_query = 5
lr = 0.001

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# Training loop
for epoch in range(n_epochs):
    print(f"Epoch: {epoch + 1}/{n_epochs}")

    support_set, query_set, support_labels, query_labels = create_few_shot_task(train_values, np.array(train_matrix_labels), n_way, k_shot, n_query)
    support_set = torch.tensor(support_set, dtype=torch.float32)
    query_set = torch.tensor(query_set, dtype=torch.float32)
    support_labels = torch.tensor(support_labels, dtype=torch.long)
#     print(support_labels)
    model.train()
    optimizer.zero_grad()
    scores = model(support_set, support_labels, query_set)
    loss = criterion(scores, torch.tensor(query_labels, dtype=torch.long))

    loss.backward()
    optimizer.step()
#     print(scores)
    # Compute accuracy
    _, predictions = torch.max(scores, 1)
#     print(predictions)
#     print(query_labels)
    accuracy = accuracy_score(query_labels, predictions.detach().numpy())
    
    # Calculate Silhouette Coefficient
    with torch.no_grad():
        query_embeddings = model.backbone.forward(query_set)
    silhouette_coefficient = silhouette_score(query_embeddings.detach().numpy(), query_labels)

#     print(f"Loss: {loss.item()}, Accuracy: {accuracy * 100}%")
    print(f"Loss: {loss.item()}, Accuracy: {accuracy * 100}%, Silhouette Coefficient: {silhouette_coefficient}")
# Out:
# Epoch: 1/100
# Loss: 0.9209780097007751, Accuracy: 76.0%
# Loss: 0.9209780097007751, Accuracy: 76.0%, Silhouette Coefficient: 0.28050750494003296
# Epoch: 2/100
# Loss: 0.8113956451416016, Accuracy: 68.0%
# Loss: 0.8113956451416016, Accuracy: 68.0%, Silhouette Coefficient: 0.25324082374572754
# Epoch: 3/100
# Loss: 0.7578932046890259, Accuracy: 80.0%
# Loss: 0.7578932046890259, Accuracy: 80.0%, Silhouette Coefficient: 0.2785293161869049
# Epoch: 4/100
# Loss: 0.652604341506958, Accuracy: 72.0%
# Loss: 0.652604341506958, Accuracy: 72.0%, Silhouette Coefficient: 0.29935646057128906
# Epoch: 5/100
# Loss: 0.6010200381278992, Accuracy: 76.0%
# Loss: 0.6010200381278992, Accuracy: 76.0%, Silhouette Coefficient: 0.2490777224302292
# Epoch: 6/100
# Loss: 0.5389792323112488, Accuracy: 84.0%
# Loss: 0.5389792323112488, Accuracy: 84.0%, Silhouette Coefficient: 0.2982012927532196
# Epoch: 7/100
# Loss: 0.43274182081222534, Accuracy: 96.0%
# Loss: 0.43274182081222534, Accuracy: 96.0%, Silhouette Coefficient: 0.3874549865722656
# Epoch: 8/100
# Loss: 0.4303990602493286, Accuracy: 88.0%
# Loss: 0.4303990602493286, Accuracy: 88.0%, Silhouette Coefficient: 0.3545101583003998
# Epoch: 9/100
# Loss: 0.406650573015213, Accuracy: 92.0%
# Loss: 0.406650573015213, Accuracy: 92.0%, Silhouette Coefficient: 0.38466334342956543
# Epoch: 10/100
# Loss: 0.4221082925796509, Accuracy: 84.0%
# Loss: 0.4221082925796509, Accuracy: 84.0%, Silhouette Coefficient: 0.3650411367416382
# Epoch: 11/100
# Loss: 0.31748563051223755, Accuracy: 92.0%
# Loss: 0.31748563051223755, Accuracy: 92.0%, Silhouette Coefficient: 0.44584494829177856
# Epoch: 12/100
# Loss: 0.37461647391319275, Accuracy: 88.0%
# Loss: 0.37461647391319275, Accuracy: 88.0%, Silhouette Coefficient: 0.39018699526786804
# Epoch: 13/100
# Loss: 0.5974236726760864, Accuracy: 88.0%
# Loss: 0.5974236726760864, Accuracy: 88.0%, Silhouette Coefficient: 0.38357582688331604
# Epoch: 14/100
# Loss: 0.5318806767463684, Accuracy: 84.0%
# Loss: 0.5318806767463684, Accuracy: 84.0%, Silhouette Coefficient: 0.3347355127334595
# Epoch: 15/100
# Loss: 0.37757763266563416, Accuracy: 88.0%
# Loss: 0.37757763266563416, Accuracy: 88.0%, Silhouette Coefficient: 0.42269161343574524
# Epoch: 16/100
# Loss: 0.3480987250804901, Accuracy: 92.0%
# Loss: 0.3480987250804901, Accuracy: 92.0%, Silhouette Coefficient: 0.41454488039016724
# Epoch: 17/100
# Loss: 0.2850129008293152, Accuracy: 96.0%
# Loss: 0.2850129008293152, Accuracy: 96.0%, Silhouette Coefficient: 0.49780547618865967
# Epoch: 18/100
# Loss: 0.319932758808136, Accuracy: 96.0%
# Loss: 0.319932758808136, Accuracy: 96.0%, Silhouette Coefficient: 0.43495193123817444
# Epoch: 19/100
# Loss: 0.31021541357040405, Accuracy: 96.0%
# Loss: 0.31021541357040405, Accuracy: 96.0%, Silhouette Coefficient: 0.3961199223995209
# Epoch: 20/100
# Loss: 0.2757505476474762, Accuracy: 96.0%
# Loss: 0.2757505476474762, Accuracy: 96.0%, Silhouette Coefficient: 0.4397590160369873
# Epoch: 21/100
# Loss: 0.2863968312740326, Accuracy: 96.0%
# Loss: 0.2863968312740326, Accuracy: 96.0%, Silhouette Coefficient: 0.48610737919807434
# Epoch: 22/100
# Loss: 0.23606374859809875, Accuracy: 96.0%
# Loss: 0.23606374859809875, Accuracy: 96.0%, Silhouette Coefficient: 0.5069135427474976
# Epoch: 23/100
# Loss: 0.2772059142589569, Accuracy: 92.0%
# Loss: 0.2772059142589569, Accuracy: 92.0%, Silhouette Coefficient: 0.46008220314979553
# Epoch: 24/100
# Loss: 0.22534222900867462, Accuracy: 100.0%
# Loss: 0.22534222900867462, Accuracy: 100.0%, Silhouette Coefficient: 0.5244048833847046
# Epoch: 25/100
# Loss: 0.2511349320411682, Accuracy: 96.0%
# Loss: 0.2511349320411682, Accuracy: 96.0%, Silhouette Coefficient: 0.4688255786895752
# Epoch: 26/100
# Loss: 0.21907643973827362, Accuracy: 100.0%
# Loss: 0.21907643973827362, Accuracy: 100.0%, Silhouette Coefficient: 0.571682333946228
# Epoch: 27/100
# Loss: 0.2643216550350189, Accuracy: 96.0%
# Loss: 0.2643216550350189, Accuracy: 96.0%, Silhouette Coefficient: 0.4924754798412323
# Epoch: 28/100
# Loss: 0.2078864425420761, Accuracy: 100.0%
# Loss: 0.2078864425420761, Accuracy: 100.0%, Silhouette Coefficient: 0.5196744203567505
# Epoch: 29/100
# Loss: 0.2010916769504547, Accuracy: 96.0%
# Loss: 0.2010916769504547, Accuracy: 96.0%, Silhouette Coefficient: 0.5048196911811829
# Epoch: 30/100
# Loss: 0.2319878339767456, Accuracy: 96.0%
# Loss: 0.2319878339767456, Accuracy: 96.0%, Silhouette Coefficient: 0.4938249886035919
# Epoch: 31/100
# Loss: 0.23692573606967926, Accuracy: 92.0%
# Loss: 0.23692573606967926, Accuracy: 92.0%, Silhouette Coefficient: 0.4545258581638336
# Epoch: 32/100
# Loss: 0.19682441651821136, Accuracy: 96.0%
# Loss: 0.19682441651821136, Accuracy: 96.0%, Silhouette Coefficient: 0.5738805532455444
# Epoch: 33/100
# Loss: 0.19994066655635834, Accuracy: 96.0%
# Loss: 0.19994066655635834, Accuracy: 96.0%, Silhouette Coefficient: 0.5381613373756409
# Epoch: 34/100
# Loss: 0.2474825531244278, Accuracy: 92.0%
# Loss: 0.2474825531244278, Accuracy: 92.0%, Silhouette Coefficient: 0.5244630575180054
# Epoch: 35/100
# Loss: 0.18175211548805237, Accuracy: 96.0%
# Loss: 0.18175211548805237, Accuracy: 96.0%, Silhouette Coefficient: 0.5537808537483215
# Epoch: 36/100
# Loss: 0.17234736680984497, Accuracy: 100.0%
# Loss: 0.17234736680984497, Accuracy: 100.0%, Silhouette Coefficient: 0.5340547561645508
# Epoch: 37/100
# Loss: 0.21347413957118988, Accuracy: 92.0%
# Loss: 0.21347413957118988, Accuracy: 92.0%, Silhouette Coefficient: 0.5871435403823853
# Epoch: 38/100
# Loss: 0.18983951210975647, Accuracy: 100.0%
# Loss: 0.18983951210975647, Accuracy: 100.0%, Silhouette Coefficient: 0.5207173824310303
# Epoch: 39/100
# Loss: 0.15609775483608246, Accuracy: 100.0%
# Loss: 0.15609775483608246, Accuracy: 100.0%, Silhouette Coefficient: 0.5739992260932922
# Epoch: 40/100
# Loss: 0.1189582422375679, Accuracy: 100.0%
# Loss: 0.1189582422375679, Accuracy: 100.0%, Silhouette Coefficient: 0.6160529255867004
# Epoch: 41/100
# Loss: 0.18968230485916138, Accuracy: 100.0%
# Loss: 0.18968230485916138, Accuracy: 100.0%, Silhouette Coefficient: 0.4868972897529602
# Epoch: 42/100
# Loss: 0.15861107409000397, Accuracy: 96.0%
# Loss: 0.15861107409000397, Accuracy: 96.0%, Silhouette Coefficient: 0.594545304775238
# Epoch: 43/100
# Loss: 0.12453879415988922, Accuracy: 100.0%
# Loss: 0.12453879415988922, Accuracy: 100.0%, Silhouette Coefficient: 0.6306180357933044
# Epoch: 44/100
# Loss: 0.1559668779373169, Accuracy: 100.0%
# Loss: 0.1559668779373169, Accuracy: 100.0%, Silhouette Coefficient: 0.5631569027900696
# Epoch: 45/100
# Loss: 0.12802207469940186, Accuracy: 100.0%
# Loss: 0.12802207469940186, Accuracy: 100.0%, Silhouette Coefficient: 0.6017197966575623
# Epoch: 46/100
# Loss: 0.1282324343919754, Accuracy: 100.0%
# Loss: 0.1282324343919754, Accuracy: 100.0%, Silhouette Coefficient: 0.5998908877372742
# Epoch: 47/100
# Loss: 0.11983932554721832, Accuracy: 100.0%
# Loss: 0.11983932554721832, Accuracy: 100.0%, Silhouette Coefficient: 0.5847392082214355
# Epoch: 48/100
# Loss: 0.19974388182163239, Accuracy: 96.0%
# Loss: 0.19974388182163239, Accuracy: 96.0%, Silhouette Coefficient: 0.5415825843811035
# Epoch: 49/100
# Loss: 0.11309125274419785, Accuracy: 100.0%
# Loss: 0.11309125274419785, Accuracy: 100.0%, Silhouette Coefficient: 0.6094412803649902
# Epoch: 50/100
# Loss: 0.14187274873256683, Accuracy: 96.0%
# Loss: 0.14187274873256683, Accuracy: 96.0%, Silhouette Coefficient: 0.5365464687347412
# Epoch: 51/100
# Loss: 0.11581716686487198, Accuracy: 100.0%
# Loss: 0.11581716686487198, Accuracy: 100.0%, Silhouette Coefficient: 0.5704642534255981
# Epoch: 52/100
# Loss: 0.13829532265663147, Accuracy: 100.0%
# Loss: 0.13829532265663147, Accuracy: 100.0%, Silhouette Coefficient: 0.5934607982635498
# Epoch: 53/100
# Loss: 0.15385593473911285, Accuracy: 100.0%
# Loss: 0.15385593473911285, Accuracy: 100.0%, Silhouette Coefficient: 0.5863213539123535
# Epoch: 54/100
# Loss: 0.13555006682872772, Accuracy: 96.0%
# Loss: 0.13555006682872772, Accuracy: 96.0%, Silhouette Coefficient: 0.5659489035606384
# Epoch: 55/100
# Loss: 0.13765880465507507, Accuracy: 96.0%
# Loss: 0.13765880465507507, Accuracy: 96.0%, Silhouette Coefficient: 0.6021223664283752
# Epoch: 56/100
# Loss: 0.20499543845653534, Accuracy: 96.0%
# Loss: 0.20499543845653534, Accuracy: 96.0%, Silhouette Coefficient: 0.5909237265586853
# Epoch: 57/100
# Loss: 0.10378187894821167, Accuracy: 100.0%
# Loss: 0.10378187894821167, Accuracy: 100.0%, Silhouette Coefficient: 0.5989894866943359
# Epoch: 58/100
# Loss: 0.12680689990520477, Accuracy: 100.0%
# Loss: 0.12680689990520477, Accuracy: 100.0%, Silhouette Coefficient: 0.5926822423934937
# Epoch: 59/100
# Loss: 0.08472520858049393, Accuracy: 100.0%
# Loss: 0.08472520858049393, Accuracy: 100.0%, Silhouette Coefficient: 0.6604803204536438
# Epoch: 60/100
# Loss: 0.13028313219547272, Accuracy: 96.0%
# Loss: 0.13028313219547272, Accuracy: 96.0%, Silhouette Coefficient: 0.6224206686019897
# Epoch: 61/100
# Loss: 0.1337299793958664, Accuracy: 100.0%
# Loss: 0.1337299793958664, Accuracy: 100.0%, Silhouette Coefficient: 0.5578732490539551
# Epoch: 62/100
# Loss: 0.16265414655208588, Accuracy: 96.0%
# Loss: 0.16265414655208588, Accuracy: 96.0%, Silhouette Coefficient: 0.5613939166069031
# Epoch: 63/100
# Loss: 0.09466950595378876, Accuracy: 100.0%
# Loss: 0.09466950595378876, Accuracy: 100.0%, Silhouette Coefficient: 0.6536514163017273
# Epoch: 64/100
# Loss: 0.14745016396045685, Accuracy: 96.0%
# Loss: 0.14745016396045685, Accuracy: 96.0%, Silhouette Coefficient: 0.6088672280311584
# Epoch: 65/100
# Loss: 0.11898232251405716, Accuracy: 96.0%
# Loss: 0.11898232251405716, Accuracy: 96.0%, Silhouette Coefficient: 0.6279310584068298
# Epoch: 66/100
# Loss: 0.10958756506443024, Accuracy: 100.0%
# Loss: 0.10958756506443024, Accuracy: 100.0%, Silhouette Coefficient: 0.6517800092697144
# Epoch: 67/100
# Loss: 0.1196615919470787, Accuracy: 100.0%
# Loss: 0.1196615919470787, Accuracy: 100.0%, Silhouette Coefficient: 0.5814584493637085
# Epoch: 68/100
# Loss: 0.10214656591415405, Accuracy: 100.0%
# Loss: 0.10214656591415405, Accuracy: 100.0%, Silhouette Coefficient: 0.6466893553733826
# Epoch: 69/100
# Loss: 0.17728695273399353, Accuracy: 96.0%
# Loss: 0.17728695273399353, Accuracy: 96.0%, Silhouette Coefficient: 0.5572507977485657
# Epoch: 70/100
# Loss: 0.09152698516845703, Accuracy: 100.0%
# Loss: 0.09152698516845703, Accuracy: 100.0%, Silhouette Coefficient: 0.6495854258537292
# Epoch: 71/100
# Loss: 0.10160234570503235, Accuracy: 100.0%
# Loss: 0.10160234570503235, Accuracy: 100.0%, Silhouette Coefficient: 0.6400424838066101
# Epoch: 72/100
# Loss: 0.16214899718761444, Accuracy: 96.0%
# Loss: 0.16214899718761444, Accuracy: 96.0%, Silhouette Coefficient: 0.5735005140304565
# Epoch: 73/100
# Loss: 0.11743156611919403, Accuracy: 96.0%
# Loss: 0.11743156611919403, Accuracy: 96.0%, Silhouette Coefficient: 0.6297141909599304
# Epoch: 74/100
# Loss: 0.1452876180410385, Accuracy: 96.0%
# Loss: 0.1452876180410385, Accuracy: 96.0%, Silhouette Coefficient: 0.6035940051078796
# Epoch: 75/100
# Loss: 0.07621137797832489, Accuracy: 100.0%
# Loss: 0.07621137797832489, Accuracy: 100.0%, Silhouette Coefficient: 0.6865770220756531
# Epoch: 76/100
# Loss: 0.0840194895863533, Accuracy: 100.0%
# Loss: 0.0840194895863533, Accuracy: 100.0%, Silhouette Coefficient: 0.6653531789779663
# Epoch: 77/100
# Loss: 0.11778703331947327, Accuracy: 100.0%
# Loss: 0.11778703331947327, Accuracy: 100.0%, Silhouette Coefficient: 0.5912211537361145
# Epoch: 78/100
# Loss: 0.1164010688662529, Accuracy: 96.0%
# Loss: 0.1164010688662529, Accuracy: 96.0%, Silhouette Coefficient: 0.638455331325531
# Epoch: 79/100
# Loss: 0.09281812608242035, Accuracy: 100.0%
# Loss: 0.09281812608242035, Accuracy: 100.0%, Silhouette Coefficient: 0.6086905598640442
# Epoch: 80/100
# Loss: 0.09701919555664062, Accuracy: 100.0%
# Loss: 0.09701919555664062, Accuracy: 100.0%, Silhouette Coefficient: 0.6178838014602661
# Epoch: 81/100
# Loss: 0.08974900841712952, Accuracy: 100.0%
# Loss: 0.08974900841712952, Accuracy: 100.0%, Silhouette Coefficient: 0.66672682762146
# Epoch: 82/100
# Loss: 0.10802402347326279, Accuracy: 96.0%
# Loss: 0.10802402347326279, Accuracy: 96.0%, Silhouette Coefficient: 0.597619354724884
# Epoch: 83/100
# Loss: 0.111297108232975, Accuracy: 96.0%
# Loss: 0.111297108232975, Accuracy: 96.0%, Silhouette Coefficient: 0.5760399103164673
# Epoch: 84/100
# Loss: 0.12912343442440033, Accuracy: 100.0%
# Loss: 0.12912343442440033, Accuracy: 100.0%, Silhouette Coefficient: 0.6012181639671326
# Epoch: 85/100
# Loss: 0.07980992645025253, Accuracy: 100.0%
# Loss: 0.07980992645025253, Accuracy: 100.0%, Silhouette Coefficient: 0.6625003218650818
# Epoch: 86/100
# Loss: 0.10986282676458359, Accuracy: 100.0%
# Loss: 0.10986282676458359, Accuracy: 100.0%, Silhouette Coefficient: 0.6073535680770874
# Epoch: 87/100
# Loss: 0.11182553321123123, Accuracy: 100.0%
# Loss: 0.11182553321123123, Accuracy: 100.0%, Silhouette Coefficient: 0.6373953819274902
# Epoch: 88/100
# Loss: 0.08509354293346405, Accuracy: 100.0%
# Loss: 0.08509354293346405, Accuracy: 100.0%, Silhouette Coefficient: 0.6209131479263306
# Epoch: 89/100
# Loss: 0.11621609330177307, Accuracy: 100.0%
# Loss: 0.11621609330177307, Accuracy: 100.0%, Silhouette Coefficient: 0.6210395097732544
# Epoch: 90/100
# Loss: 0.08409418165683746, Accuracy: 100.0%
# Loss: 0.08409418165683746, Accuracy: 100.0%, Silhouette Coefficient: 0.6727774739265442
# Epoch: 91/100
# Loss: 0.08581572771072388, Accuracy: 100.0%
# Loss: 0.08581572771072388, Accuracy: 100.0%, Silhouette Coefficient: 0.6243217587471008
# Epoch: 92/100
# Loss: 0.10793233662843704, Accuracy: 96.0%
# Loss: 0.10793233662843704, Accuracy: 96.0%, Silhouette Coefficient: 0.6498466730117798
# Epoch: 93/100
# Loss: 0.0759602040052414, Accuracy: 100.0%
# Loss: 0.0759602040052414, Accuracy: 100.0%, Silhouette Coefficient: 0.6145759224891663
# Epoch: 94/100
# Loss: 0.10749191045761108, Accuracy: 96.0%
# Loss: 0.10749191045761108, Accuracy: 96.0%, Silhouette Coefficient: 0.6546568274497986
# Epoch: 95/100
# Loss: 0.07259980589151382, Accuracy: 100.0%
# Loss: 0.07259980589151382, Accuracy: 100.0%, Silhouette Coefficient: 0.6799097657203674
# Epoch: 96/100
# Loss: 0.15369506180286407, Accuracy: 96.0%
# Loss: 0.15369506180286407, Accuracy: 96.0%, Silhouette Coefficient: 0.6143795251846313
# Epoch: 97/100
# Loss: 0.12022198736667633, Accuracy: 96.0%
# Loss: 0.12022198736667633, Accuracy: 96.0%, Silhouette Coefficient: 0.6176932454109192
# Epoch: 98/100
# Loss: 0.0755399689078331, Accuracy: 100.0%
# Loss: 0.0755399689078331, Accuracy: 100.0%, Silhouette Coefficient: 0.6994359493255615
# Epoch: 99/100
# Loss: 0.0645880401134491, Accuracy: 100.0%
# Loss: 0.0645880401134491, Accuracy: 100.0%, Silhouette Coefficient: 0.7243995070457458
# Epoch: 100/100
# Loss: 0.07421226054430008, Accuracy: 100.0%
# Loss: 0.07421226054430008, Accuracy: 100.0%, Silhouette Coefficient: 0.6579176187515259

# %%
# Your code for loading the data (unchanged)
input_file = "/kaggle/input/5way-5shot/test_LSA64_5way_5shot_suppot_query.csv"

values = []
matrix_labels = []
num_rows = 0

with open(input_file, "r") as f_input:
    reader = csv.reader(f_input)
    for row in reader:
        row_values = []
        for i in range(len(row) - 1):
            column_value = ast.literal_eval(row[i])
            row_values.append(column_value)
        values.append(torch.tensor(row_values))
        matrix_labels.append(ast.literal_eval(row[-1]))
        num_rows += 1
        
matrix_labels = np.array(matrix_labels)

# %%
test_values = torch.stack(values)
test_matrix_labels = matrix_labels

# %%
# Set the number of evaluation episodes
n_evaluation_episodes = 100

# Initialize the accuracy accumulator
total_accuracy = 0

# Set the model to evaluation mode
model.eval()

# Evaluation loop
for episode in range(n_evaluation_episodes):
    support_set, query_set, support_labels, query_labels = create_few_shot_task(test_values, np.array(test_matrix_labels), n_way, k_shot, n_query)
    support_set = torch.tensor(support_set, dtype=torch.float32)
    query_set = torch.tensor(query_set, dtype=torch.float32)
    support_labels = torch.tensor(support_labels, dtype=torch.long) 
#     print(support_labels)
    with torch.no_grad():
        scores = model(support_set, support_labels, query_set)
#         print(scores.shape)
#         print(scores)
        # Compute accuracy
        _, predictions = torch.max(scores, 1)
#         print(predictions.detach().numpy())
#         print(query_labels)
        accuracy = accuracy_score(query_labels, predictions.detach().numpy())
        print(accuracy)
        # Calculate Silhouette Coefficient
        with torch.no_grad():
            query_embeddings = model.backbone.forward(query_set)
            silhouette_coefficient = silhouette_score(query_embeddings.detach().numpy(), query_labels)
        total_accuracy += accuracy
        print("Accuracy: {:.2%}, Silhouette Coefficient: {:.2f}".format(accuracy, silhouette_coefficient))

# Compute the average accuracy over all evaluation episodes
average_accuracy = total_accuracy / n_evaluation_episodes
print(f"Average accuracy: {average_accuracy * 100}%")
# Out:
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.48
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.33
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.46
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.54
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.38
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.40
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.41
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.39
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.43
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.51
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.37
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.37
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.48
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.47
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.49
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.36
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.36
# 0.76
# Accuracy: 76.00%, Silhouette Coefficient: 0.25
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.50
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.44
# 0.8
# Accuracy: 80.00%, Silhouette Coefficient: 0.40
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.59
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.41
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.44
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.41
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.38
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.41
# 0.76
# Accuracy: 76.00%, Silhouette Coefficient: 0.31
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.53
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.45
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.35
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.52
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.42
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.38
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.43
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.41
# 0.8
# Accuracy: 80.00%, Silhouette Coefficient: 0.32
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.33
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.25
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.47
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.51
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.51
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.35
# 0.8
# Accuracy: 80.00%, Silhouette Coefficient: 0.35
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.30
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.34
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.43
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.45
# 0.76
# Accuracy: 76.00%, Silhouette Coefficient: 0.27
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.36
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.35
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.54
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.48
# 0.8
# Accuracy: 80.00%, Silhouette Coefficient: 0.32
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.48
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.55
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.36
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.44
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.43
# 0.76
# Accuracy: 76.00%, Silhouette Coefficient: 0.29
# 0.76
# Accuracy: 76.00%, Silhouette Coefficient: 0.26
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.37
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.41
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.36
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.41
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.40
# 0.8
# Accuracy: 80.00%, Silhouette Coefficient: 0.27
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.47
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.48
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.28
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.39
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.43
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.44
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.53
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.41
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.53
# 0.8
# Accuracy: 80.00%, Silhouette Coefficient: 0.36
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.44
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.42
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.49
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.56
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.36
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.48
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.46
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.46
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.40
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.40
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.45
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.48
# 0.8
# Accuracy: 80.00%, Silhouette Coefficient: 0.33
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.51
# 1.0
# Accuracy: 100.00%, Silhouette Coefficient: 0.46
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.35
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.41
# 0.96
# Accuracy: 96.00%, Silhouette Coefficient: 0.37
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.43
# 0.92
# Accuracy: 92.00%, Silhouette Coefficient: 0.46
# 0.84
# Accuracy: 84.00%, Silhouette Coefficient: 0.44
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.41
# 0.88
# Accuracy: 88.00%, Silhouette Coefficient: 0.41
# Average accuracy: 89.6%
